# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
train_loss = pd.read_csv("paper/第一版/csv/class6_training_avg_loss.csv")
train_loss.head()
# Out:
#       Wall time  Step     Value
# 0  1.645702e+09     1  0.031758
# 1  1.645702e+09     2  0.034686
# 2  1.645702e+09     3  0.018286
# 3  1.645702e+09     4  0.015267
# 4  1.645702e+09     5  0.007932

# %%
plt.style.use('seaborn-whitegrid')

plt.figure(figsize=(5,3))

plt.plot(train_loss['Step'][:15], train_loss['Value'][:15], linewidth=2.0)

plt.ylim=(0,0.045)

plt.xlabel("epoch")

plt.ylabel("train_avg_loss")

plt.show()

# %%
val_loss = pd.read_csv("paper/第一版/csv/class6_validation_avg_loss.csv")
val_loss.head()
# Out:
#       Wall time  Step     Value
# 0  1.645702e+09     1  0.029271
# 1  1.645702e+09     2  0.031334
# 2  1.645702e+09     3  0.017309
# 3  1.645702e+09     4  0.016041
# 4  1.645702e+09     5  0.007735

# %%
plt.style.use('seaborn-whitegrid')

plt.figure(figsize=(5,3))

plt.plot(val_loss['Step'][:15], val_loss['Value'][:15], linewidth=2.0)

# plt.ylim=(0,0.045)

plt.xlabel("epoch")

plt.ylabel("val_avg_loss")

plt.show()

# %% [markdown]
# # 合并

# %%
plt.style.use('seaborn-whitegrid')

plt.figure(figsize=(5,3),dpi=300)

p1, = plt.plot(train_loss['Step'][:15], train_loss['Value'][:15], linewidth=2.0)
p2, = plt.plot(val_loss['Step'][:15], val_loss['Value'][:15], linewidth=2.0)

# plt.ylim=(0,0.045)

plt.legend([p1,p2],['class6_train','class6_val'],loc='best')

plt.xlabel("epoch")
plt.ylabel("avg_loss")

plt.show()

# %%
from mpl_toolkits.axes_grid1 import host_subplot
import matplotlib.pyplot as plt

host = host_subplot(111)

par = host.twinx()

host.set_xlabel("Epoch")
host.set_ylabel("Avg Loss")
par.set_ylabel("Time(s)")

p1, = host.plot(train_loss['Step'][:15], train_loss['Value'][:15], label="Class6_Train Loss")
p2, = host.plot(val_loss['Step'][:15], val_loss['Value'][:15], label="Class6_Val Loss")
p3, = par.plot(range(1,16), [23,46,70,93,116,139,162,185,209,232,255,278,303,327,351], label="Time")

leg = plt.legend()

# host.yaxis.get_label().set_color(p1.get_color())
# leg.texts[0].set_color(p1.get_color())

# par.yaxis.get_label().set_color(p2.get_color())
# leg.texts[1].set_color(p2.get_color())

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# 数据
t = np.arange(0.01, 10.0, 0.01)
data1 = np.exp(t)
data2 = np.sin(2 * np.pi * t)

fig, ax1 = plt.subplots(figsize=(10, 5))

color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('exp', color=color)
line1 = ax1.plot(t, data1, color=color,label='y1')
ax1.tick_params(axis='y', labelcolor=color)

# 实例化共享同一x轴的第二个轴
ax2 = ax1.twinx()

color = 'tab:blue'
ax2.set_ylabel('sin', color=color)
line2 = ax2.plot(t, data2, color=color,label='y2')
ax2.tick_params(axis='y', labelcolor=color)

ax1.legend()
ax2.legend()

fig.tight_layout()

# %%
# -*- coding: utf-8 -*-
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
rc('mathtext', default='regular')

time = np.arange(10)
temp = np.random.random(10)*30
Swdown = np.random.random(10)*100-10
Rn = np.random.random(10)*100-10

fig = plt.figure()
ax = fig.add_subplot(111)

lns1 = ax.plot(time, Swdown, '-', label = 'Swdown')
lns2 = ax.plot(time, Rn, '-', label = 'Rn')
ax2 = ax.twinx()
lns3 = ax2.plot(time, temp, '-r', label = 'temp')

# added these three lines
lns = lns1+lns2+lns3
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc=0)

ax.grid()
ax.set_xlabel("Time (h)")
ax.set_ylabel(r"Radiation ($MJ\,m^{-2}\,d^{-1}$)")
ax2.set_ylabel(r"Temperature ($^\circ$C)")
ax2.set_ylim(0, 35)
ax.set_ylim(-20,100)
# Out:
# (-20.0, 100.0)

# %%
# -*- coding: utf-8 -*-
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,10)
y = np.linspace(0,10)
z = np.sin(x/3)**2*98

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x,y, '-', label = 'Quantity 1')

ax2 = ax.twinx()
ax2.plot(x,z, '-r', label = 'Quantity 2')
fig.legend(loc=1, bbox_to_anchor=(1,1), bbox_transform=ax.transAxes)

ax.set_xlabel("x [units]")
ax.set_ylabel(r"Quantity 1")
ax2.set_ylabel(r"Quantity 2")
